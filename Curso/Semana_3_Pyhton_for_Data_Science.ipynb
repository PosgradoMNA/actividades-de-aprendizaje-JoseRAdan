# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-de-aprendizaje-JoseRAdan/blob/main/Curso/Semana_3_Pyhton_for_Data_Science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Semana 3 - Python for Data Science**
# #**Python for Data Science - Módulo 5 y Examen Final**
#
# ###**Ciencia y Analítica de Datos**
# ###**Nombre del estudiante: (José Ramiro Adán Charles)**
# ###**Matrícula: (A00174646)**

# %% [markdown]
# **NOTAS:**
#
#
#
# # Learning Objectives
#
# 1. Explain the use of the HTTP protocol using the Requests Library method
# 2. Describe how the URL Request Response HTTP protocol works
# 3. Learn to apply simple, open-source APIs
# 4. Perform basic webscraping using Python
# 5. Work with different file formats using Python
# 6. Explain the difference between APIs and REST APIs
# 7. Summarize how APIs receive and send information

# %% [markdown]
# # Labs
# ### **[Quizz 1](https://github.com/PosgradoMNA/actividades-de-aprendizaje-JoseRAdan/blob/025799bd51f3ea1c12b1a40c4e0f55d04d96d28d/Curso/Module%205_5.1_notebook_quizz_numpy1d.jupyterlite.ipynb)**
#
# ### **[Quizz 2](https://github.com/PosgradoMNA/actividades-de-aprendizaje-JoseRAdan/blob/025799bd51f3ea1c12b1a40c4e0f55d04d96d28d/Curso/Module%205_5.2_notebook_quizz_numpy.jupyterlite.ipynb)**
#
# ### **[Lab 1](https://github.com/PosgradoMNA/actividades-de-aprendizaje-JoseRAdan/blob/025799bd51f3ea1c12b1a40c4e0f55d04d96d28d/Curso/Module%205_PY0101EN-5-1-Numpy1D.ipynb)**
#
# ### **[Lab 2](https://github.com/PosgradoMNA/actividades-de-aprendizaje-JoseRAdan/blob/025799bd51f3ea1c12b1a40c4e0f55d04d96d28d/Curso/Module%205_PY0101EN-5-2-Numpy2D.ipynb)**
#
# ### **[Lab 3](https://github.com/PosgradoMNA/actividades-de-aprendizaje-JoseRAdan/blob/025799bd51f3ea1c12b1a40c4e0f55d04d96d28d/Curso/PY0101EN-5.2_API_2.v2.ipynb)**
#
# ### **[Lab 4](https://github.com/PosgradoMNA/actividades-de-aprendizaje-JoseRAdan/blob/025799bd51f3ea1c12b1a40c4e0f55d04d96d28d/Curso/PY0101EN-5.3_Requests_HTTP.ipynb)**
#
# ### **[CERTIFICADO ;)](https://github.com/PosgradoMNA/actividades-de-aprendizaje-JoseRAdan/blob/b925eff10d64f9bc6d6bce6c118ef04e520af20b/Curso/IBM%20PY0101EN%20Certificate%20Cognitive%20Class.pdf)**
#
#
# ### PROGRESO
# ![Snip_22-10-04_22-00-08.png](data:image/png;base64,...)
